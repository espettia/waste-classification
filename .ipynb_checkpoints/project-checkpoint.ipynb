# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.applications.xception import Xception
from tensorflow.keras.applications.xception import preprocess_input
from tensorflow.keras.applications.xception import decode_predictions
from tensorflow.keras.preprocessing.image import ImageDataGenerator
# Out:
# 2023-12-20 03:09:15.831509: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
train_gen = ImageDataGenerator(preprocessing_function=preprocess_input)
train_ds = train_gen.flow_from_directory(
    './RealWaste-train',
    target_size=(150, 150),
    batch_size=32
)

val_gen = ImageDataGenerator(preprocessing_function=preprocess_input)
val_ds = val_gen.flow_from_directory(
    './RealWaste-validation',
    target_size=(150, 150),
    batch_size=32,
    shuffle=False
)
# Out:
# Found 3354 images belonging to 9 classes.
# Found 718 images belonging to 9 classes.

# %% [markdown]
# ## First, we will find the optimal learning-rate

# %%
def make_model(input_size=150, learning_rate=0.01):

    base_model = Xception(
        weights='imagenet',
        include_top=False,
        input_shape=(input_size, input_size, 3)
    )

    base_model.trainable = False

    #########################################

    inputs = keras.Input(shape=(input_size, input_size, 3))
    base = base_model(inputs, training=False)
    vectors = keras.layers.GlobalAveragePooling2D()(base)
    outputs = keras.layers.Dense(9)(vectors)
    
    model = keras.Model(inputs, outputs)
    
    #########################################

    optimizer = keras.optimizers.Adam(learning_rate=learning_rate)
    loss = keras.losses.CategoricalCrossentropy(from_logits=True)

    model.compile(
        optimizer=optimizer,
        loss=loss,
        metrics=['accuracy']
    )
    
    return model

# %%
checkpoint = keras.callbacks.ModelCheckpoint(
    'xception_v4_final_{epoch:02d}_{val_accuracy:.3f}.h5',
    save_best_only=True,
    monitor='val_accuracy',
    mode='max'
)

# %%
input_size=150
lrs = np.power(10.0,-np.arange(1,5))
scores = {}
for lr in lrs:
    model = make_model(
        input_size=input_size,
        learning_rate=lr
    )
    history = model.fit(train_ds, epochs=10, validation_data=val_ds,
                       callbacks=[])
    scores[lr]=history.history
# Out:
# Epoch 1/10
# 105/105 [==============================] - 22s 187ms/step - loss: 13.0568 - accuracy: 0.5572 - val_loss: 9.8475 - val_accuracy: 0.6630
# Epoch 2/10
# 105/105 [==============================] - 19s 179ms/step - loss: 6.7491 - accuracy: 0.7254 - val_loss: 10.9882 - val_accuracy: 0.6393
# Epoch 3/10
# 105/105 [==============================] - 19s 179ms/step - loss: 5.6569 - accuracy: 0.7683 - val_loss: 13.1424 - val_accuracy: 0.6769
# Epoch 4/10
# 105/105 [==============================] - 19s 179ms/step - loss: 4.6697 - accuracy: 0.8080 - val_loss: 12.5711 - val_accuracy: 0.6838
# Epoch 5/10
# 105/105 [==============================] - 19s 180ms/step - loss: 3.5348 - accuracy: 0.8432 - val_loss: 12.9989 - val_accuracy: 0.6852
# Epoch 6/10
# 105/105 [==============================] - 19s 179ms/step - loss: 2.2417 - accuracy: 0.8900 - val_loss: 11.6549 - val_accuracy: 0.6838
# Epoch 7/10
# ...

# %%
for lr, hist in scores.items():
    plt.plot(hist['val_accuracy'], label=('val=%s' % lr))

plt.xticks(np.arange(10))
plt.legend()

# %%
learning_rate = 0.001

# %% [markdown]
# ## Now, we try adding an inner layer and tuning its size

# %%
def make_model(input_size=150, learning_rate=0.01, size_inner=100):

    base_model = Xception(
        weights='imagenet',
        include_top=False,
        input_shape=(input_size, input_size, 3)
    )

    base_model.trainable = False

    #########################################

    inputs = keras.Input(shape=(input_size, input_size, 3))
    base = base_model(inputs, training=False)
    vectors = keras.layers.GlobalAveragePooling2D()(base)
    
    inner = keras.layers.Dense(size_inner, activation='relu')(vectors)
    outputs = keras.layers.Dense(9)(inner)
    
    model = keras.Model(inputs, outputs)
    
    #########################################

    optimizer = keras.optimizers.Adam(learning_rate=learning_rate)
    loss = keras.losses.CategoricalCrossentropy(from_logits=True)

    model.compile(
        optimizer=optimizer,
        loss=loss,
        metrics=['accuracy']
    )
    
    return model

# %%
input_size=150
sizes = np.power(10.0,np.arange(1,4))
scores = {}
for size in sizes:
    model = make_model(
        input_size=input_size,
        learning_rate=learning_rate,
        size_inner = size
    )
    history = model.fit(train_ds, epochs=10, validation_data=val_ds,
                       callbacks=[])
    scores[size]=history.history
# Out:
# Epoch 1/10
# 105/105 [==============================] - 22s 187ms/step - loss: 1.5177 - accuracy: 0.4618 - val_loss: 1.2271 - val_accuracy: 0.5752
# Epoch 2/10
# 105/105 [==============================] - 19s 179ms/step - loss: 1.0125 - accuracy: 0.6622 - val_loss: 1.0077 - val_accuracy: 0.6546
# Epoch 3/10
# 105/105 [==============================] - 19s 180ms/step - loss: 0.8019 - accuracy: 0.7308 - val_loss: 0.9166 - val_accuracy: 0.6852
# Epoch 4/10
# 105/105 [==============================] - 19s 179ms/step - loss: 0.6723 - accuracy: 0.7779 - val_loss: 0.9218 - val_accuracy: 0.6741
# Epoch 5/10
# 105/105 [==============================] - 19s 181ms/step - loss: 0.5852 - accuracy: 0.8062 - val_loss: 0.8705 - val_accuracy: 0.6922
# Epoch 6/10
# 105/105 [==============================] - 19s 180ms/step - loss: 0.5064 - accuracy: 0.8390 - val_loss: 0.8383 - val_accuracy: 0.7103
# Epoch 7/10
# ...

# %%
for size, hist in scores.items():
    plt.plot(hist['val_accuracy'], label=('size=%s' % size))

plt.xticks(np.arange(10))
plt.legend()

# %%
size = 1000

# %% [markdown]
# ## Dropout
# Tuning of dropout rate

# %%
def make_model(input_size=150, learning_rate=0.01, size_inner=100,
               droprate=0.5):

    base_model = Xception(
        weights='imagenet',
        include_top=False,
        input_shape=(input_size, input_size, 3)
    )

    base_model.trainable = False

    #########################################

    inputs = keras.Input(shape=(input_size, input_size, 3))
    base = base_model(inputs, training=False)
    vectors = keras.layers.GlobalAveragePooling2D()(base)
    
    inner = keras.layers.Dense(size_inner, activation='relu')(vectors)
    drop = keras.layers.Dropout(droprate)(inner)
    
    outputs = keras.layers.Dense(9)(drop)
    
    model = keras.Model(inputs, outputs)
    
    #########################################

    optimizer = keras.optimizers.Adam(learning_rate=learning_rate)
    loss = keras.losses.CategoricalCrossentropy(from_logits=True)

    model.compile(
        optimizer=optimizer,
        loss=loss,
        metrics=['accuracy']
    )
    
    return model

# %%
droprates = np.arange(0,10,2)/10
scores = {}
for droprate in droprates:

    model = make_model(
        input_size=input_size,
        learning_rate=learning_rate,
        size_inner=size,
        droprate=droprate
    )

    history = model.fit(train_ds, epochs=20, validation_data=val_ds,
                       callbacks=[checkpoint])
    scores[droprate] = history.history
# Out:
# Epoch 1/20
# 105/105 [==============================] - 22s 189ms/step - loss: 1.1432 - accuracy: 0.6130 - val_loss: 0.9396 - val_accuracy: 0.6657
# Epoch 2/20
# 105/105 [==============================] - 19s 179ms/step - loss: 0.5391 - accuracy: 0.8038 - val_loss: 0.8569 - val_accuracy: 0.7061
# Epoch 3/20
# 105/105 [==============================] - 19s 181ms/step - loss: 0.3188 - accuracy: 0.8986 - val_loss: 0.7917 - val_accuracy: 0.7354
# Epoch 4/20
# 105/105 [==============================] - 19s 178ms/step - loss: 0.1653 - accuracy: 0.9484 - val_loss: 0.8545 - val_accuracy: 0.7298
# Epoch 5/20
# 105/105 [==============================] - 19s 181ms/step - loss: 0.0737 - accuracy: 0.9857 - val_loss: 0.8511 - val_accuracy: 0.7591
# Epoch 6/20
# 105/105 [==============================] - 19s 178ms/step - loss: 0.0300 - accuracy: 0.9970 - val_loss: 0.9675 - val_accuracy: 0.7535
# Epoch 7/20
# ...

# %%
for droprate, hist in scores.items():
    plt.plot(hist['val_accuracy'], label=('droprate=%s' % droprate))

plt.xticks(np.arange(20))
plt.legend()

# %%
droprate = 0

# %% [markdown]
# ## Augmentations

# %%
images = tf.keras.utils.image_dataset_from_directory(
  './RealWaste')
# Out:
# Found 4790 files belonging to 9 classes.

# %%
from PIL.Image import fromarray

# %%
i=0
for batch in images:
    for image in batch[0]:
        display(fromarray(np.array(image).round().astype('uint8')))
        i+=1
        if i==10:
            break
    break
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>
# <PIL.Image.Image image mode=RGB size=256x256>
# <PIL.Image.Image image mode=RGB size=256x256>
# <PIL.Image.Image image mode=RGB size=256x256>
# <PIL.Image.Image image mode=RGB size=256x256>
# <PIL.Image.Image image mode=RGB size=256x256>
# <PIL.Image.Image image mode=RGB size=256x256>
# <PIL.Image.Image image mode=RGB size=256x256>
# <PIL.Image.Image image mode=RGB size=256x256>
# <PIL.Image.Image image mode=RGB size=256x256>

# %% [markdown]
# ### We can see that rotation may help with the training. For example, bottles may appear in different orientations.
# ### Also, shearing will help as there are different shapes for shards of glass, bottles, and folded paper
# ### Shift won't help as all images are centered
# ### Zooming may not be as useful, because all images are about the same size
# ### Channel shift may be helpful as some training examples appear bluer or warmer.

# %%
train_gen = ImageDataGenerator(preprocessing_function=preprocess_input,
                               shear_range=10,
                               rotation_range=45,
                               channel_shift_range=75.0)
train_ds = train_gen.flow_from_directory(
    './RealWaste-train',
    target_size=(150, 150),
    batch_size=32
)
# Out:
# Found 3354 images belonging to 9 classes.

# %%
def make_model(input_size=150, learning_rate=0.01, size_inner=100,
               droprate=0.5):

    base_model = Xception(
        weights='imagenet',
        include_top=False,
        input_shape=(input_size, input_size, 3)
    )

    base_model.trainable = False

    #########################################

    inputs = keras.Input(shape=(input_size, input_size, 3))
    base = base_model(inputs, training=False)
    vectors = keras.layers.GlobalAveragePooling2D()(base)
    
    inner = keras.layers.Dense(size_inner, activation='relu')(vectors)
    drop = keras.layers.Dropout(droprate)(inner)
    
    outputs = keras.layers.Dense(9)(drop)
    
    model = keras.Model(inputs, outputs)
    
    #########################################

    optimizer = keras.optimizers.Adam(learning_rate=learning_rate)
    loss = keras.losses.CategoricalCrossentropy(from_logits=True)

    model.compile(
        optimizer=optimizer,
        loss=loss,
        metrics=['accuracy']
    )
    
    return model

# %%
model = make_model(
    input_size=input_size,
    learning_rate=learning_rate,
    size_inner=size,
    droprate=droprate
)

history = model.fit(train_ds, epochs=20, validation_data=val_ds,
                   callbacks=[checkpoint])
# Out:
# Epoch 1/20
# 105/105 [==============================] - 35s 312ms/step - loss: 1.2240 - accuracy: 0.5909 - val_loss: 0.9411 - val_accuracy: 0.6518
# Epoch 2/20
# 105/105 [==============================] - 32s 302ms/step - loss: 0.8003 - accuracy: 0.7224 - val_loss: 0.8690 - val_accuracy: 0.6783
# Epoch 3/20
# 105/105 [==============================] - 32s 304ms/step - loss: 0.6570 - accuracy: 0.7809 - val_loss: 0.7879 - val_accuracy: 0.7061
# Epoch 4/20
# 105/105 [==============================] - 32s 303ms/step - loss: 0.5864 - accuracy: 0.7907 - val_loss: 0.7939 - val_accuracy: 0.6978
# Epoch 5/20
# 105/105 [==============================] - 32s 302ms/step - loss: 0.5436 - accuracy: 0.8065 - val_loss: 0.8733 - val_accuracy: 0.7033
# Epoch 6/20
# 105/105 [==============================] - 32s 304ms/step - loss: 0.4827 - accuracy: 0.8247 - val_loss: 0.7237 - val_accuracy: 0.7451
# Epoch 7/20
# ...

# %%
plt.plot(history.history['val_accuracy'])
plt.yticks(np.linspace(0.7,0.9,10))
print(history.history['val_accuracy'])
plt.show()
# Out:
# [0.6518105864524841, 0.6782729625701904, 0.7061281204223633, 0.6977716088294983, 0.703342616558075, 0.7451253533363342, 0.7172701954841614, 0.7534818649291992, 0.7339832782745361, 0.7506963610649109, 0.7284122705459595, 0.7409470677375793, 0.7562674283981323, 0.7520891427993774, 0.7451253533363342, 0.7562674283981323, 0.7674094438552856, 0.7729805111885071, 0.7548746466636658, 0.7660167217254639]

# %% [markdown]
# ## It's possible that with further training the model becomes better as we see in the graph the accuracy is ever increasing, so we will use the augmentations. Also we will train a larger model, so features as wrinkles and patterns of food may become even more visible

# %%
input_size=299

train_gen = ImageDataGenerator(preprocessing_function=preprocess_input,
                               shear_range=10,
                               rotation_range=45,
                               channel_shift_range=75.0)
train_ds = train_gen.flow_from_directory(
    './RealWaste-train',
    target_size=(input_size, input_size),
    batch_size=32
)

val_gen = ImageDataGenerator(preprocessing_function=preprocess_input)
val_ds = val_gen.flow_from_directory(
    './RealWaste-validation',
    target_size=(input_size, input_size),
    batch_size=32,
    shuffle=False
)

model = make_model(
    input_size=input_size,
    learning_rate=learning_rate,
    size_inner=size,
    droprate=droprate
)

ckpt = keras.callbacks.ModelCheckpoint(
    'xception_v4_final_{epoch:02d}_{val_accuracy:.3f}.h5',
    save_best_only=True,
    monitor='val_accuracy',
    mode='max'
)

history = model.fit(train_ds, epochs=50, validation_data=val_ds,
                   callbacks=[ckpt])
# Out:
# Found 3354 images belonging to 9 classes.
# Found 718 images belonging to 9 classes.
# Epoch 1/50
# 105/105 [==============================] - 82s 745ms/step - loss: 0.9410 - accuracy: 0.6699 - val_loss: 0.7347 - val_accuracy: 0.7312
# Epoch 2/50
# 105/105 [==============================] - 76s 727ms/step - loss: 0.6325 - accuracy: 0.7806 - val_loss: 0.6870 - val_accuracy: 0.7479
# Epoch 3/50
# 105/105 [==============================] - 77s 732ms/step - loss: 0.4889 - accuracy: 0.8259 - val_loss: 0.6212 - val_accuracy: 0.7604
# Epoch 4/50
# 105/105 [==============================] - 77s 729ms/step - loss: 0.4149 - accuracy: 0.8524 - val_loss: 0.7433 - val_accuracy: 0.7479
# Epoch 5/50
# 105/105 [==============================] - 77s 732ms/step - loss: 0.3568 - accuracy: 0.8775 - val_loss: 0.6142 - val_accuracy: 0.7730
# Epoch 6/50
# 105/105 [==============================] - 77s 734ms/step - loss: 0.3134 - accuracy: 0.8840 - val_loss: 0.5572 - val_accuracy: 0.8036
# Epoch 7/50
# ...

# %%
plt.plot(history.history['val_accuracy'])
plt.yticks(np.linspace(0.8,0.9,10))
plt.show()

# %% [markdown]
# ## A maximum accuracy of 0.855 has been reached in the validation dataset.

# %%
test_gen = ImageDataGenerator(preprocessing_function=preprocess_input)
test_ds = val_gen.flow_from_directory(
    './RealWaste-test',
    target_size=(input_size, input_size),
    batch_size=32,
    shuffle=False
)

model = keras.models.load_model('xception_v4_final_46_0.855.h5')

model.evaluate(test_ds)
# Out:
# Found 718 images belonging to 9 classes.
# 23/23 [==============================] - 6s 210ms/step - loss: 0.6704 - accuracy: 0.8454
# [0.6703884601593018, 0.8454039096832275]

# %% [markdown]
# ## Final score on test dataset: 0.845

# %% [markdown]
# ## Using the model

# %%
path = 'test.jpeg'
img = load_img(path, target_size=(299, 299))

# %%
x = np.array(img)
X = np.array([x])
X.shape
# Out:
# (1, 299, 299, 3)

# %%
X = preprocess_input(X)
pred = model.predict(X)
classes = images.class_names
# Out:
# 1/1 [==============================] - 0s 21ms/step

# %%
dict(zip(classes, pred[0]))
# Out:
# {'Cardboard': -10.748851,
#  'Food Organics': -12.850723,
#  'Glass': -5.762827,
#  'Metal': 15.945985,
#  'Miscellaneous Trash': -12.147714,
#  'Paper': 3.9086514,
#  'Plastic': -7.4049006,
#  'Textile Trash': -6.515926,
#  'Vegetation': -18.089695}

# %% [markdown]
# ## Having played with the final model I observe that the model has problems differentiating paper from glass when the shapes are sharp. Also paper from cardboard and plastic from metal, the errors seem reasonable
